# %%
# Set your Git user email to GitHub's no-reply address
git config user.email "jorgemenv@users.noreply.github.com"

# Verify it's set
git config user.email

# If you need to amend the most recent commit with the new email:
git commit --amend --reset-author --no-edit

# Then push
git push
